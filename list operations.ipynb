# %%
lst=[20,12,342,54]
lst
# Out:
# [20, 12, 342, 54]

# %%
print(max(lst))
# Out:
# 342

# %%
print(min(lst))
print(sum(lst))
print(len(lst))
print(sum(lst)/4)
# Out:
# 12
# 428
# 4
# 107.0

# %%
lst.append(20)
lst=[1,2,3,4]

# %%
for i in lst:
    if(i%2==0):
        print(i)
# Out:
# 2
# 4

# %%
for i in lst:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
